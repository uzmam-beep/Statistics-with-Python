# %%
import pandas as pd 
import matplotlib.pyplot as plt
data = pd.read_csv('weather2021.txt')
plt.figure()
plt.scatter(data.maxtemp,data.mintemp,marker='.')
plt.xlabel('maxtemp')
plt.ylabel('mintemp')
plt.axis([0,27.5,-7.5,17.5])
# Out:
# (0.0, 27.5, -7.5, 17.5)
